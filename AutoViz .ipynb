# %%
#importing Autoviz class
from autoviz.AutoViz_Class import AutoViz_Class
#Instantiate the AutoViz class
AV = AutoViz_Class()
# Out:
# Imported AutoViz_Class version: 0.0.68. Call using:
#     from autoviz.AutoViz_Class import AutoViz_Class
#     AV = AutoViz_Class()
#     AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
#
# To remove previous versions, perform 'pip uninstall autoviz'

# %%
df = AV.AutoViz('Downloads/car_design.csv')
# Out:
# Shape of your Data Set: (205, 26)
# Classifying variables in data set...
#     26 Predictors classified...
#         This does not include the Target column(s)
#     3 variables removed since they were ID or low-information variables
# Number of All Scatter Plots = 3
# Number of Categorical and Continuous Vars exceeds limit, hence no Bar Plots
# Time to run AutoViz (in seconds) = 3.169

# %%
dft1 = AV.AutoViz("Downloads/Advertising.csv", depVar='Sales')
# Out:
# Shape of your Data Set: (200, 4)
# Classifying variables in data set...
#     3 Predictors classified...
#         This does not include the Target column(s)
#     No variables removed since no ID or low-information variables found in data set
# Number of All Scatter Plots = 6
# No categorical or boolean vars in data set. Hence no pivot plots...
# Nothing to add Plot not being added
# No categorical or boolean vars in data set. Hence no bar charts.
# Nothing to add Plot not being added
# All Plots done
# Time to run AutoViz (in seconds) = 1.353
