# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Data Science\\Project\\Household Price Analysis.csv')

# %%
df
# Out:
#     ID  Local Price  Bathrooms Count  Area_Sqft  Living Space  Garrage Count  \
# 0    1       4.9176              1.0     3.4720        0.9980            1.0
# 1    2       5.0208              1.0     3.5310        1.5000            2.0
# 2    3       4.5429              1.0     2.2750        1.1750            1.0
# 3    4       4.5573              1.0     4.0500        1.2320            1.0
# 4    5       5.0597              1.0     4.4550        1.1210            1.0
# 5    6       3.8910              1.0     4.4550        0.9880            1.0
# 6    7       5.8980              1.0     5.8500        1.2400            1.0
# 7    8       5.6039              1.0     9.5200        1.5010            0.0
# 8    9      16.4202              2.5     9.8000        3.4200            2.0
# 9   10      14.4598              2.5    12.8000        3.0000            2.0
# 10  11       5.8282              1.0     6.4350        1.2250            2.0
# ...

# %%
df.corr()
# Out:
#                        ID  Local Price  Bathrooms Count  Area_Sqft  \
# ID               1.000000     0.100951         0.262272   0.070128
# Local Price      0.100951     1.000000         0.442454   0.311146
# Bathrooms Count  0.262272     0.442454         1.000000   0.612422
# Area_Sqft        0.070128     0.311146         0.612422   1.000000
# Living Space    -0.123616     0.439033         0.537542   0.648941
# Garrage Count   -0.031247     0.280286         0.327696   0.424984
# Rooms Count     -0.034193     0.236704         0.463433   0.555061
# Bedrooms Count  -0.073737     0.281522         0.263029   0.476592
# Age             -0.075901    -0.177871         0.015913  -0.222979
# Selling Price   -0.229985     0.790234         0.526322   0.513818
# Unnamed: 12           NaN          NaN              NaN        NaN
# Unnamed: 13           NaN          NaN              NaN        NaN
# Unnamed: 14           NaN          NaN              NaN        NaN
# ...

# %%
df.describe()
# Out:
#               ID  Local Price  Bathrooms Count  Area_Sqft  Living Space  \
# count  57.000000    57.000000        57.000000  57.000000     57.000000
# mean   29.000000     7.355858         1.377193   6.417904      1.428242
# std    16.598193     3.002137         0.502500   2.418404      0.609202
# min     1.000000     2.851100         1.000000   1.147300      0.125500
# 25%    15.000000     5.276500         1.000000   4.996900      1.107400
# 50%    29.000000     6.258200         1.000000   6.123600      1.357100
# 75%    43.000000     9.038400         1.500000   7.800000      1.683100
# max    57.000000    16.420200         3.000000  12.800000      3.420000
#
#        Garrage Count  Rooms Count  Bedrooms Count        Age  Selling Price  \
# count      57.000000    57.000000       57.000000  57.000000      57.000000
# mean        1.280702     6.526316        3.245614  36.035088      34.270175
# std         0.619746     2.391243        1.313130  13.947561      12.821229
# ...

# %%
plt.scatter(df['Selling Price'], df['Area_Sqft'])
plt.title('Price vs Square feet')
# Out:
# Text(0.5, 1.0, 'Price vs Square feet')

# %%
from scipy.stats import pearsonr,spearmanr

# %%
df.columns
# Out:
# Index(['ID', 'Local Price', 'Bathrooms Count', 'Area_Sqft', 'Living Space',
#        'Garrage Count', 'Rooms Count', 'Bedrooms Count', 'Age', 'Material',
#        'Level', 'Selling Price', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17'],
#       dtype='object')

# %%
x = df[['Local Price', 'Bathrooms Count', 'Area_Sqft', 'Living Space',
       'Garrage Count', 'Rooms Count', 'Bedrooms Count', 'Age']]

# %%
y = df['Selling Price']

# %%
import statsmodels as sm

# %%
import statsmodels as sm

# %%
import statsmodels.formula.api as smf

# %%
sns.distplot(df['Selling Price'].dropna(),kde=True, bins=30)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print(lm.intercept_)
# Out:
# 3.545282455587582

# %%
lm.coef_
# Out:
# array([ 2.32208791, -3.05108217, -0.06950994, 18.99329819,  1.33754046,
#         0.10053665, -3.79238008,  0.03064876])

# %%
predictions = lm.predict(x)

# %%
predictions
# Out:
# array([18.78629759, 30.5069874 , 24.99177434, 26.41353294, 25.07595711,
#        20.26510701, 29.56217504, 31.56099471, 84.32840231, 70.63176408,
#        29.72920781, 33.41590817, 28.36617526, 28.04204152, 25.57412485,
#        31.56099471, 39.20668885, 34.30891956, 33.76979145, 41.46777789,
#        31.00111234, 39.54083768, 43.11429587, 35.9389087 , 41.27900889,
#        39.49948027, 43.05493847, 42.09874566, 25.28161333, 27.97368941,
#        37.95838505, 47.7603718 , 25.43010631, 33.45117297, 21.54812984,
#        38.24584717, 19.97628142, 51.76493753, 21.00335646, 43.75066495,
#        24.82295032, 53.1788015 , 38.36592646, 38.10032914, 38.59082036,
#        20.65763053, 42.31515478, 44.83044851, 31.11313617, 44.28630833,
#        17.21364005, 28.20014089, 28.387042  , 37.32981475, 23.56373672,
#        13.98977132, 31.21784146])

# %%
plt.scatter(y, predictions)

# %%
sns.distplot((y-predictions))

# %%
model = smf.ols('y~x',df)

# %%
model

# %%
results = model.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.907
# Model:                            OLS   Adj. R-squared:                  0.892
# Method:                 Least Squares   F-statistic:                     58.80
# Date:                Tue, 12 Nov 2019   Prob (F-statistic):           3.49e-22
# Time:                        11:16:50   Log-Likelihood:                -157.97
# No. Observations:                  57   AIC:                             333.9
# Df Residuals:                      48   BIC:                             352.3
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.5453      3.053      1.161      0.251      -2.592       9.683
# ...

# %%
df.isnull().sum()
# Out:
# ID                  0
# Local Price         0
# Bathrooms Count     0
# Area_Sqft           0
# Living Space        0
# Garrage Count       0
# Rooms Count         0
# Bedrooms Count      0
# Age                 0
# Material            0
# Level               0
# Selling Price       0
# Unnamed: 12        57
# Unnamed: 13        57
# Unnamed: 14        57
# Unnamed: 15        57
# Unnamed: 16        55
# Unnamed: 17        55
# dtype: int64

# %%
sns.regplot(x='Area_Sqft',y='Selling Price',data=df)
